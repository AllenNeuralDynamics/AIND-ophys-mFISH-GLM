# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
glm_results_fn = '/root/capsule/scratch/glm/721291_2024-05-17_glm_v03/glm_results_v03_721291_2024-05-17_events.npy'
results = np.load(glm_results_fn, allow_pickle=True).item()

# %%
results.keys(
)
# Out:
# dict_keys(['fit_params', 'use_indices', 'stratified_frames', 'cv_inds_stratified', 'lambdas_cv', 'W_cv', 'var_explained_train_cv', 'var_explained_test_cv', 'vr_test_train_ratio_cv', 'var_explained_mean_model'])

# %%
fig, ax = plt.subplots()
ax.hist(results['lambdas_cv'].sel(model='Full').values.flatten(), bins=np.linspace(0,500,50));

# %%
fig, ax = plt.subplots()
ax.hist(results['lambdas_cv'].sel(model='Full').values.flatten(), bins=np.linspace(0,500,50));
